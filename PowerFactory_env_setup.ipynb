# %% [markdown]
# The following scripts can be used to run PowerFactory externally by Python

# %%
import sys # Add powerfactory.pyd path to python path
sys.path.append(r'C:\Program Files\DIgSILENT\PowerFactory 2025\Python\3.11')

# %%
import powerfactory as pf # Import powerfactory module
try:
        app = pf.GetApplicationExt() # External Python scripts should use GetApplicationExt()
        if not app:
            raise RuntimeError("Failed to connect to PowerFactory.")
        print("✓ Connected to PowerFactory")
except Exception as e:
        print(f"✗ Error connecting to PowerFactory: {str(e)}")
        raise
# Out:
# ✗ Error connecting to PowerFactory: Exit with error code 7000
# ---------------------------------------------------------------------------
# ExitError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import powerfactory as pf # Import powerfactory module
#       2 try:
# ----> 3         app = pf.GetApplicationExt() # External Python scripts should use GetApplicationExt()
#       4         if not app:
#       5             raise RuntimeError("Failed to connect to PowerFactory.")
#
# ExitError: Exit with error code 7000
